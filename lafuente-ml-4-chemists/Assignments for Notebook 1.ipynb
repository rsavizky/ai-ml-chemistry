# %% [markdown]
# ---
# #Assignments for notebook 1
# We prepared a series of excercises for you to put what you've learned in notebook 1 into action.
#
# ---

# %% [markdown]
# ## Excercise 1.1: Making a calculator
#
# Make different calculators by defining your own operation functions. In particular:
# * Make a function that adds numbers
# * Make a function that substracts numbers
# * Make a function that multiplies numbers
# * Make a function that divides numbers
# * Make a function that calculates a certain power of a number
# * Make a function that takes the square root of a number
# * Try out your calculators and check what "type" of result you get.
# * Print a string on the screen that "tells" you the result of your calculations (use the `str(...)` function to convert your numbers to strings)
#
#
# TIP 1: A way to do this is using the *def* and *return* commands, for example:
#
# ```
# def function_name(x, y): #x and y are the parameters that the function requires
#     return type-here-math-expression-you-want-to-perform
#
# function_name(1, 2)
# ```
# TIP 2: Python has some built-in functions that you can use such as:
# * `pow(...)`: returns the power of a number
# * `abs(...)`: returns the absolute value of a number

# %%
def add(x,y):
  return (x+y)
add(1,3)
# Out:
# 4

# %%
def substract(x,y):
  return(x-y)
substract(3,1)
# Out:
# 2

# %%
def multiply(x,y):
    return (x*y)
multiply(5,2)
# Out:
# 10

# %%
def divide(x,y):
  return(x/y)
divide(4,2)
# Out:
# 2.0

# %%
pow(3,2)
# Out:
# 9

# %%
#We can define a square root function
def sqrt(x):
  return(x**(1/2))
sqrt(9)
# Out:
# 3.0

# %%
#Check the type
type(add(1,2))
# Out:
# int

# %%
type(divide(3,2))
# Out:
# float

# %%
#Printing a string explaning the results
"The result of dividing 10 by 2 is " + str(divide(3,2)) + ". The result type is necessarily a float because it's a decimal number"
# Out:
# "The result of dividing 10 by 2 is 1.5. The result type is necessarily a float because it's a decimal number"

# %% [markdown]
# ## Excercise 1.2: Lists, strings and data types
# * Make a list that contains numbers, along with some strings. Remember that the objects of a list are inside `[]` and separated by `,`.
#
#
# * Make a function that returns the type of the different elements of the list. it should request the number of the element of the list as a parameter. Remember that, to return the type of an element you can use the `type(...)` function.

# %%
my_list=[ 3, 4.8, "cats", "mouse"]

def type_of_element (number_of_element):
    element_datatype = type(my_list[number_of_element])
    return element_datatype

type_of_element(0)
# Out:
# int

# %%
type_of_element(2)
# Out:
# str

# %% [markdown]
# ## Excercise 1.3: Dataframes
# * Load the example dataset on the seaborn library called "flights".
# * Print your dataset to see the summarized table
# * Print only the columns of this dataframe
# * Select only the column "passengers" using your previous result, set it as a list. Store this result inside a variable.
# * Select only the column "year" and do the same as with "passengers".
# * Filter the flights dataframe, keeping only the rows that correspond to a number of passengers greater than 300 . Sort the dataframe by its numbers of passengers, in ascending order.
# * Filter the flights dataframe, keeping only the rows that correspond to years before 1952. Sort the dataframe by Year, in descending order.
#
# TIPS:
# - You can load the dataset using the function "sns.load_dataset("flights")"
# - The method of a dataframe called "columns" will help you find the columns.
# - The columns method outputs a pandas object, but it can be treated as a normal "list", make use of indexing to extract the different names of columns.
# - Use boolean masks (code that establishes conditions) to filter the dataframe.
# - Storing these results in variables will help you shorten the code for boolean masks.

# %%
import seaborn as sns
flights = sns.load_dataset("flights")

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
col=flights.columns
col
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
col[2]
# Out:
# 'passengers'

# %%
col[0]
# Out:
# 'year'

# %%
#The column containing the number of passengers. Indexing by strings is used (col[2] is the string "passengers"). Remember DataFrames can be indexed by strings, in contrast to lists.
a=flights[col[2]]
a
# Out:
# 0      112
# 1      118
# 2      132
# 3      129
# 4      121
#       ...
# 139    606
# 140    508
# 141    461
# 142    390
# 143    432
# Name: passengers, Length: 144, dtype: int64

# %%
#The column containing the years.
b=flights[col[0]]
b
# Out:
# 0      1949
# 1      1949
# 2      1949
# 3      1949
# 4      1949
#        ...
# 139    1960
# 140    1960
# 141    1960
# 142    1960
# 143    1960
# Name: year, Length: 144, dtype: int64

# %%
bigger_than_300= flights[a>300]
bigger_than_300.sort_values(by=col[2], ascending=True)
# Out:
#      year month  passengers
# 97   1957   Feb         301
# 66   1954   Jul         302
# 106  1957   Nov         305
# 93   1956   Oct         306
# 95   1956   Dec         306
# ..    ...   ...         ...
# 137  1960   Jun         535
# 126  1959   Jul         548
# 127  1959   Aug         559
# 139  1960   Aug         606
# 138  1960   Jul         622
#
# [62 rows x 3 columns]

# %%
prior1952=flights[b<1952]
prior1952.sort_values(by=col[0], ascending=False)
# Out:
#     year month  passengers
# 35  1951   Dec         166
# 29  1951   Jun         178
# 24  1951   Jan         145
# 25  1951   Feb         150
# 26  1951   Mar         178
# 27  1951   Apr         163
# 28  1951   May         172
# 30  1951   Jul         199
# 31  1951   Aug         199
# 32  1951   Sep         184
# 33  1951   Oct         162
# 34  1951   Nov         146
# 19  1950   Aug         170
# 23  1950   Dec         140
# 22  1950   Nov         114
# 21  1950   Oct         133
# 20  1950   Sep         158
# 18  1950   Jul         170
# 16  1950   May         125
# 15  1950   Apr         135
# 14  1950   Mar         141
# 13  1950   Feb         126
# 12  1950   Jan         115
# 17  1950   Jun         149
# 1   1949   Feb         118
# 6   1949   Jul         148
# 2   1949   Mar         132
# 3   1949   Apr         129
# 4   1949   May         121
# 5   1949   Jun         135
# 9   1949   Oct         119
# 7   1949   Aug         148
# 8   1949   Sep         136
# ...

# %% [markdown]
# ## Excercise 1.4:
# * Load the example dataset on the seaborn library called "flights".
# * Plot the number of passengers for every year. (If you want, you could distinguish one month from another using the "hue" parameter in order to see many plots at once).
# * Can you formulate some conclusions by looking at this simple plot?
# * Make a linear regression for a month of your choice.
#
# TIP: Remember that to make a scatterplot you can use the function `sns.scatterplot(...)`. For more information about it's parameters, visit the [documentation](https://seaborn.pydata.org/generated/seaborn.scatterplot.html). To make a linear regression using seaborn you can use the function `sns.lmplot(...)`, you can also visit it's [documentation](https://seaborn.pydata.org/generated/seaborn.lmplot.html).

# %%
import seaborn as sns
flights = sns.load_dataset("flights")
sns.scatterplot(x="year", y="passengers",hue="month", data=flights)
# The highest demand for flights occurs in the middle of each year.
# Flights demand increases as time passes.
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.lmplot(x="year", y="passengers", data=flights[flights['month']=='May'])

# %% [markdown]
# ---
# # Advanced/Research Assignments
# ##### In this section we'll encourage you to investigate some new libraries, typically used on data analysis. For example, numpy is a widely used library for any algebraic task, and also provides the basis methods for many other libraries. Links for documentation will be provided for you to complete the tasks. Many of these libraries are available out of the box on Google Collab, without the need of installing them (unlike Pingouin).
#
#
# ---

# %% [markdown]
#  ### Numpy example
#  Let's say we want make an addition with numpy. Numpy has a method called `add(...)`, that uses 2 arbitrary parameters as the numbers we want to add. You can read the full numpy documentation [on this link](https://numpy.org/doc/stable/reference/routines.math.html).

# %%
import numpy as np
np.add(2,3)
# Out:
# 5

# %% [markdown]
# You can also do more operations such as convert degrees to radians. Numpy includes all the common irrational numbers like Pi.

# %%
Pi=np.pi
np.degrees(Pi)
# Out:
# 180.0

# %% [markdown]
# ### Matplotlib Example
# ##### Matplotlib is the most used plotting library for python. In some notebooks, we have used seaborn because of it's simple sintax and high applicability for statistics, nonetheless, seaborn is based on matplotlib. When you need a plot with specific headers, toolbars, titles, lables, interactivity and many other aditions, using matplotlib directly is often the way to go. [Matplotlib documentation](https://matplotlib.org/contents.html).
# ##### Here, we will only show you how to make a fairly simple plot with some labels.

# %%
import matplotlib.pyplot as plt
xvalues=[1,2,3,4] #Making a list of x values
yvalues=[3,6,9,12] #Making a list of y values
plt.xlabel("The X Values") #Putting the x labels
plt.ylabel("The Y Values") #Putting the y labels
plt.plot(xvalues, yvalues, "o") #Telling to make a plot
plt.show() #Telling python to finally show the plot

# %% [markdown]
# ### Excercise 1.5: Calculating trigonometric values
#  If we rememeber some trigonometry, sin(30°) is proven to be exactly 0.5. However, computers use Taylor series and related techniques to estimate such values. See for yourself if these two values are taken by the computer to be the same.
# ##### Show that the number 0,5 differs from sin(30°) for a computer.
# ##### TIPS:
#
# * Use numpy to calculate the sine, then make a comparison showing that the 2 values are not equal. You can check the [numpy's documentation](https://numpy.org/doc/stable/reference/generated/numpy.sin.html).
# * Define a variable "a" as 0.5, and another variable "b" as sin(30°). Once you've defined both variables,"ask" the computer if a=b.

# %% [markdown]
# Solution:
# ##### As we have seen in notebook 1, every time we work with float values we will actually be working with *approximations*, due to the fact that computers store decimal numbers as binary fractions.
# To complete the assigned task, we will need to use the numpy module.

# %%
import numpy as np
a=0.5 #We define 0,5 and we call it "a"
b=np.sin(np.radians(30)) # We calculate sine of 30° and we call it "b". Don't forget to convert the degrees to radians first.
b
# Out:
# 0.49999999999999994

# %%
a==b
# Out:
# False

# %%
a-b
# Out:
# 5.551115123125783e-17

# %% [markdown]
# As you could probably see, the calculated sin(30°) is an approximation, and, if were to use a condition that needs the difference between the two values to be zero, our code would not be effective because, for the computer, this difference is not exactly 0. Go ahead and make the substraction yourself in the code cell below, and see how the result is not 0.

# %% [markdown]
# ## Excercise 1.6:
# Redo excercise 1.1, but this time usin numpy's functions.
# You may use the [numpy's documentation](https://numpy.org/doc/stable/reference/generated/numpy.sin.html), in particular the "Arithmetic operations" section that contains all the functions you'll need.

# %% [markdown]
# Solution:

# %%
import numpy as np
np.add(2,4)
# Out:
# 6

# %%
type(np)
# Out:
# module

# %%
np.subtract(1,2)
# Out:
# -1

# %%
np.multiply(2,5)
# Out:
# 10

# %%
np.true_divide(4,2)
# Out:
# 2.0

# %%
np.power(3,2)
# Out:
# 9

# %%
np.sqrt(2)
# Out:
# 1.4142135623730951

# %% [markdown]
# ## Excercise 1.7: Scatter plot/Regression of random numbers - error bars - Matplotlib
# This will be your most comprehensive task so far, you'll need to use many libraries.
# * Generate two lists of random numbers, one for the X values of your plot and one for the Y values and sort them in ascending order.
# * Plot your list of values, put labels and a title.
# * Calculate a linear regression and show the equation on the plot.
# * Calculate error bars and put them on the plot.
#
# ##### Hints:
# * Use the native python function `random` to generate random numbers. Other useful Python functions are `range` and `random.sample` .
#
# More information on `random` function [here](https://docs.python.org/3/library/random.html).
#
# More information for `range` function [here](https://www.w3schools.com/python/ref_func_range.asp)
# * You can find information on sorting values [here](https://www.w3schools.com/python/ref_list_sort.asp)
#
# * Use numpy for the linear regression, the `polyfit` function may help. More information on said function [here](https://numpy.org/doc/stable/reference/generated/numpy.polyfit.html)
# * You can fin the documentation for matplotlib error bars [here](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.errorbar.html)

# %% [markdown]
# Solution:
# ##### First, let's automatically generate some values:

# %%
import random
#Generate 20 random numbers between 10 and 100
randomlist_x = random.sample(range(1, 60), 20)
print(randomlist_x)
# Out:
# [15, 30, 48, 49, 23, 53, 46, 10, 31, 2, 18, 27, 19, 6, 54, 5, 20, 8, 40, 33]

# %% [markdown]
# These will be our "x" values.
# Now let's generate another list of 20 random numbers between 20 and 100 to be our "y" values and name it *randomlist_y*:

# %%
#Generate 20 random numbers between 1 and 100
randomlist_y = random.sample(range(1, 60), 20)
print(randomlist_y)
# Out:
# [39, 55, 47, 11, 6, 1, 58, 54, 43, 59, 18, 21, 26, 37, 35, 2, 34, 57, 38, 8]

# %% [markdown]
# Let's use the **sort()** function on our list of x values to sort the values in ascending order. This is a built- in  Python function. If you don't enter any additional parameters, it sorts the elements in the list in ascending order. This function changes our list directly, so there's no need to define a new sorted list. Also visualize the new version of the lists by printing them, in order to make sure the values are sorted correctly.

# %%
randomlist_x.sort()
randomlist_y.sort()

print(randomlist_x)
print(randomlist_y)
# Out:
# [2, 5, 6, 8, 10, 15, 18, 19, 20, 23, 27, 30, 31, 33, 40, 46, 48, 49, 53, 54]
# [1, 2, 6, 8, 11, 18, 21, 26, 34, 35, 37, 38, 39, 43, 47, 54, 55, 57, 58, 59]

# %% [markdown]
# Let's import **numpy** and **matplotlib.pyplot** modules for our plot, and let's define our first list of numbers as our "x" values. After that do the same procedure on the second list to redefine the set of "y" values:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = randomlist_x
y = randomlist_y

# %% [markdown]
# Let's make a scatter plot with these values. Use the *scatter()* function of matplotlib.
# You can add a title to your graph witht he *title()* function, and label the axes with the xlabel() and ylabel() functions respectively.

# %%
plt.scatter(x,y, marker='o')
plt.title("Scatter Plot")
plt.xlabel('x values')
plt.ylabel("y values")
# Out:
# Text(0, 0.5, 'y values')

# %% [markdown]
# Now let's draw a trendline over the previous graph by defining a new variable as the 1-degree polynomial fit of your distribution. On numpy this function is called "polyfit", and the parameters should be x, y, and the degree of the polinomial you want to fit your distribution to.
#
# In order to make a more undestandable graph, it's better to add "legends", to label everything properly. Add an additional "label" parameter to the scatter() function, and then use the  legend() function to show these legends on the graph.

# %%
plt.scatter(x, y, label="scatter")

z = np.polyfit(x, y, 1) # z gives the slope and intercept as it's output on a list
p = np.poly1d(z) #p will give the "y" values correponding to the x values.
plt.plot(x,p(x),"r-", label="trendline")

plt.title("Scatter Plot and trendline")
plt.xlabel("x values")
plt.ylabel("y values")
plt.legend()
plt.show()

# %% [markdown]
# If we want to show the function equation, we can use:
#
#
# ```
# print("The curve fit for this function is y = {0} x + {1}.".format(z[0], z[1]))
# ```
# "z" being the fit of the 1D polynomial. z[0] the slope of the adjusted function and z[1] the intercept.

# %%
print("The curve fit for this function is y = {0:1.4E} x + {1:1.4E}.".format(z[0], z[1]))
# Out:
# The curve fit for this function is y = 1.1412E+00 x + 1.8098E+00.

# %% [markdown]
# Now let's draw some error bars. Use the *plt.errorbar()* function. You will need to add another variable: the y-error, which will be our linear regression minus the given "y" values. The parameters for your plt.errorbar() function will be these three variables.

# %%
plt.scatter(x, y, label="scatter")
plt.xlabel("x values")
plt.ylabel("y values")
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r-", label="trendline")
yerr=abs(p(x)-y) # Armaan: ABS() added to fix "ValueError: 'yerr' must not contain negative values"
plt.errorbar(x, p(x), yerr, fmt='.k',label="error")

plt.rc('font', size=18)          # controls default text sizes
plt.rc('axes', titlesize=18)     # fontsize of the axes title
plt.rc('axes', labelsize=18)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=18)    # fontsize of the tick labels
plt.rc('ytick', labelsize=18)    # fontsize of the tick labels
plt.rc('legend', fontsize=14)    # legend fontsize
plt.rc('figure', titlesize=22)  # fontsize of the figure title

plt.legend()
plt.show() 
print("The curve fit for this function is y = {0:1.4E} x + {1:1.4E}.".format(z[0], z[1]))
# Out:
# The curve fit for this function is y = 1.1412E+00 x + 1.8098E+00.
